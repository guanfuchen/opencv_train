# %%
# %matplotlib inline
import cv2
import matplotlib.pyplot as plt
from scipy import misc

# %% [markdown]
# # 参考资料
#
# [Get HOG image features from OpenCV + Python?](https://stackoverflow.com/questions/6090399/get-hog-image-features-from-opencv-python)
#
# [80行Python实现-HOG梯度特征提取](https://pengzhaoqing.github.io/%E8%AE%A1%E7%AE%97%E6%9C%BA%E8%A7%86%E8%A7%89/hog/)
#
# [图像特征提取之HOG特征](https://senitco.github.io/2017/06/10/image-feature-hog/)
#
# [Histogram of Oriented Gradients](https://www.learnopencv.com/histogram-of-oriented-gradients/) learn opencv对HOG特征的描述，值得阅读加深理解。

# %%
# cv2.HOGDescriptor?
# cv2.resize?
# misc.imresize?

# %%
img = cv2.imread('../data/lena.jpg')
img = cv2.resize(img, (64, 128)) # cv2.resize: widthxheight
# img = misc.imread('../data/lena.jpg')
# img = misc.imresize(img, (128, 64)) # misc imresize: heightxwidth

# %%
plt.imshow(img)

# %%
hog = cv2.HOGDescriptor()

# %%
img_hog = hog.compute(img)

# %%
img_hog.shape # 7*15*8
# Out:
# (3780, 1)
