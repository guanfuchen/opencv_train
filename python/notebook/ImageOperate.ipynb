# %%
# %matplotlib inline
import cv2
import matplotlib.pyplot as plt

# %%
# cv2.imread?

# %%
img_src = cv2.imread('../../data/lena.jpg')

# %%
img_src.shape
# Out:
# (512, 512, 3)

# %%
img_src = cv2.imread('../../data/lena.jpg', cv2.IMREAD_COLOR)

# %%
img_src.shape
# Out:
# (512, 512, 3)

# %%
img_src = cv2.imread('../../data/lena.jpg', cv2.IMREAD_GRAYSCALE)

# %%
img_src.shape
# Out:
# (512, 512)

# %%
img_src = cv2.imread('../../data/lena.jpg', cv2.IMREAD_UNCHANGED)

# %%
img_src.shape
# Out:
# (512, 512, 3)

# %%
cv2.IMREAD_GRAYSCALE
# Out:
# 0L

# %%
cv2.IMREAD_COLOR
# Out:
# 1L

# %%
cv2.IMREAD_UNCHANGED
# Out:
# -1L

# %%
# cv2.imshow('img_src', img_src)

# %%
cv2.imwrite('/tmp/lena.jpg', img_src)
# Out:
# True

# %%
img_gray = cv2.imread('../../data/lena.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray, cmap='gray', interpolation='bicubic')
plt.xticks([])
plt.yticks([])
plt.show()
