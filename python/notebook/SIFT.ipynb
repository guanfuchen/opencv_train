# %%
# %matplotlib inline
import cv2
import matplotlib.pyplot as plt
from scipy import misc

# %%
# cv2.drawKeypoints?
# cv2.SIFT?

# %%
def bgr_to_rgb(bgr):
    rgb = cv2.cvtColor(bgr, cv2.COLOR_BGR2RGB)
    return rgb
def rgb_to_bgr(rgb):
    bgr = cv2.cvtColor(rgb, cv2.COLOR_RGB2BGR)
    return bgr

# %%
sift = cv2.SIFT()

# %%
cv2.__version__
# Out:
# '2.4.13.2'

# %%
img = cv2.imread('../../data/lena.jpg')

# %%
kp, des = sift.detectAndCompute(img, None)

# %%
des.shape
# Out:
# (1111, 128)

# %%
type(kp)
# Out:
# list

# %%
len(kp)
# Out:
# 1111

# %%
kp_0 = kp[0]
print('kp_0.angle:', kp_0.angle)
print('kp_0.size:', kp_0.size)
print('kp_0.class_id:', kp_0.class_id)
print('kp_0.pt:', kp_0.pt)
# Out:
# ('kp_0.angle:', 105.04345703125)
# ('kp_0.size:', 1.8954962491989136)
# ('kp_0.class_id:', -1)
# ('kp_0.pt:', (244.6779022216797, 46.75584411621094))

# %%
plt.imshow(rgb_to_bgr(cv2.drawKeypoints(img, kp)))

# %%
from siftdetector import detect_keypoints
keypoints, descriptors = detect_keypoints('../../data/lena.jpg', threshold=5)
# Out:
# /Library/Python/2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# Constructing pyramids...
# /Library/Python/2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# Starting extrema detection...
# First octave
# siftdetector.py:115: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   x_hat = numpy.linalg.lstsq(H, dD)[0]
# Second octave
# ...

# %%
keypoints.shape
# Out:
# (1028, 4)

# %%
img_rgb = misc.imread('../../data/lena.jpg')
for keypoint in keypoints:
    row = int(keypoint[0])
    col = int(keypoint[1])
#     print('keypoint.shape:', keypoint.shape)
#     print('keypoint:', keypoint)
#     print('x:', x)
#     print('y:', y)
    cv2.circle(img_rgb, center=(col, row), radius=3, color=(255, 0, 0))
plt.imshow(img_rgb)
